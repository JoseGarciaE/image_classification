# %%
import os

import numpy as np
import matplotlib.pyplot as plt

import cv2

# %%
from sklearn.model_selection import train_test_split

import torch
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class createDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.tensor(features)
        self.labels =  torch.tensor(labels)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, index):
        return self.features[index], self.labels[index]

class NeuralNetwork(nn.Module):	
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        # 3 input image channel, 6 output channels, 
        # 5x5 square convolution kernel
        self.conv1 = nn.Conv2d(3, 6, 5)
        # max pooling over a (2, 2) window
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5) 
        self.fc1 = nn.Linear(16 * 5 * 5, 120)# 34x34 from image dimension
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
if __name__ == '__main__':
    
    photos_path = './photos/'

    # lists to hold each data value and their respective label
    features, labels = [], []

    encoding = {}
    # re-sizing images and extracting RGB
    for i, dir in enumerate(os.listdir(photos_path)):
        encoding[dir] = i
        for file in os.listdir(os.path.join(photos_path, dir)):
            img = cv2.imread(os.path.join(photos_path, dir, file))
            img = cv2.resize(img, dsize=(32,32))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            
            img = (img / 127.5) - 1.0
                        
#             plt.imshow(img)
#             plt.show()
                        
            features.append(img.T)
            labels.append(i)
            

    # split data 
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size= 1/4)

    
    # create dataset object using torch parent class 'Dataset'
    train_data = createDataset(np.array(X_train), np.array(y_train))
    test_data = createDataset(np.array(X_test), np.array(y_test))

    # creating DataLoaders which feed batch_size number of images to the NN 
    batch_size = 5
    train_loader = DataLoader(train_data, batch_size)
    test_loader = DataLoader(test_data, batch_size)

    model = NeuralNetwork()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=.001, momentum=0.9)

    model = model.float()


    for epoch in range(100):

        running_loss = 0.0
        for i, data in enumerate(train_loader, 0):

            inputs, labels = data
            
            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = model(inputs.float())
            loss = criterion(outputs, labels.long())
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            if i % 9 == 0:    # print every 2 mini-batches
                print('Epoch')
                print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 10))
                running_loss = 0.0

    
    # prepare to count predictions for each class
    classes = os.listdir('./photos')
    correct_pred = {classname: 0 for classname in classes}
    total_pred = {classname: 0 for classname in classes}

    # no gradients required
    with torch.no_grad():
        for data in test_loader:
            features, labels = data
            outputs = model(features.float())
            _, predictions = torch.max(outputs,1)
            print(outputs, predictions)
            # collect the correct predictions for each class
            for label, prediction in zip(labels, predictions):
                if label == prediction:
                    correct_pred[classes[label]] += 1
                total_pred[classes[label]] += 1

    # print accuracy for each class
    for classname, correct_count in correct_pred.items():
        accuracy = 100 * float(correct_count) / total_pred[classname]
        print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Epoch
# [1,     1] loss: 0.070
# Epoch
# [1,    10] loss: 0.620
# Epoch
# [1,    19] loss: 0.618
# Epoch
# [1,    28] loss: 0.630
# Epoch
# [1,    37] loss: 0.628
# Epoch
# [1,    46] loss: 0.626
# Epoch
# [2,     1] loss: 0.070
# Epoch
# [2,    10] loss: 0.617
# Epoch
# [2,    19] loss: 0.615
# Epoch
# [2,    28] loss: 0.626
# Epoch
# [2,    37] loss: 0.625
# Epoch
# [2,    46] loss: 0.622
# Epoch
# [3,     1] loss: 0.070
# Epoch
# [3,    10] loss: 0.613
# Epoch
# [3,    19] loss: 0.610
# Epoch
# [3,    28] loss: 0.621
# Epoch
# [3,    37] loss: 0.620
# Epoch
# [3,    46] loss: 0.616
# Epoch
# [4,     1] loss: 0.070
# Epoch
# [4,    10] loss: 0.605
# Epoch
# [4,    19] loss: 0.601
# Epoch
# [4,    28] loss: 0.609
# Epoch
# [4,    37] loss: 0.610
# Epoch
# [4,    46] loss: 0.601
# Epoch
# [5,     1] loss: 0.069
# Epoch
# [5,    10] loss: 0.586
# Epoch
# [5,    19] loss: 0.576
# Epoch
# [5,    28] loss: 0.581
# Epoch
# [5,    37] loss: 0.587
# Epoch
# [5,    46] loss: 0.560
# Epoch
# [6,     1] loss: 0.067
# Epoch
# [6,    10] loss: 0.534
# Epoch
# [6,    19] loss: 0.504
# Epoch
# [6,    28] loss: 0.502
# Epoch
# [6,    37] loss: 0.526
# Epoch
# [6,    46] loss: 0.443
# Epoch
# [7,     1] loss: 0.058
# Epoch
# [7,    10] loss: 0.392
# Epoch
# [7,    19] loss: 0.334
# Epoch
# [7,    28] loss: 0.318
# Epoch
# [7,    37] loss: 0.424
# Epoch
# [7,    46] loss: 0.241
# Epoch
# [8,     1] loss: 0.035
# Epoch
# [8,    10] loss: 0.220
# Epoch
# [8,    19] loss: 0.169
# Epoch
# [8,    28] loss: 0.105
# Epoch
# [8,    37] loss: 0.342
# Epoch
# [8,    46] loss: 0.125
# Epoch
# [9,     1] loss: 0.021
# Epoch
# [9,    10] loss: 0.132
# Epoch
# [9,    19] loss: 0.102
# Epoch
# [9,    28] loss: 0.034
# Epoch
# [9,    37] loss: 0.302
# Epoch
# [9,    46] loss: 0.134
# Epoch
# [10,     1] loss: 0.011
# Epoch
# [10,    10] loss: 0.108
# Epoch
# [10,    19] loss: 0.079
# Epoch
# [10,    28] loss: 0.021
# Epoch
# [10,    37] loss: 0.253
# Epoch
# [10,    46] loss: 0.142
# Epoch
# [11,     1] loss: 0.005
# Epoch
# [11,    10] loss: 0.104
# Epoch
# [11,    19] loss: 0.065
# Epoch
# [11,    28] loss: 0.014
# Epoch
# [11,    37] loss: 0.219
# Epoch
# [11,    46] loss: 0.152
# Epoch
# [12,     1] loss: 0.004
# Epoch
# [12,    10] loss: 0.110
# Epoch
# [12,    19] loss: 0.068
# Epoch
# [12,    28] loss: 0.010
# Epoch
# [12,    37] loss: 0.209
# Epoch
# [12,    46] loss: 0.149
# Epoch
# [13,     1] loss: 0.005
# Epoch
# [13,    10] loss: 0.122
# Epoch
# [13,    19] loss: 0.076
# Epoch
# [13,    28] loss: 0.009
# Epoch
# [13,    37] loss: 0.202
# Epoch
# [13,    46] loss: 0.139
# Epoch
# [14,     1] loss: 0.008
# Epoch
# [14,    10] loss: 0.111
# Epoch
# [14,    19] loss: 0.066
# Epoch
# [14,    28] loss: 0.010
# Epoch
# [14,    37] loss: 0.173
# Epoch
# [14,    46] loss: 0.123
# Epoch
# [15,     1] loss: 0.006
# Epoch
# [15,    10] loss: 0.112
# Epoch
# [15,    19] loss: 0.065
# Epoch
# [15,    28] loss: 0.007
# Epoch
# [15,    37] loss: 0.163
# Epoch
# [15,    46] loss: 0.128
# Epoch
# [16,     1] loss: 0.005
# Epoch
# [16,    10] loss: 0.104
# Epoch
# [16,    19] loss: 0.060
# Epoch
# [16,    28] loss: 0.008
# Epoch
# [16,    37] loss: 0.133
# Epoch
# [16,    46] loss: 0.110
# Epoch
# [17,     1] loss: 0.004
# Epoch
# [17,    10] loss: 0.097
# Epoch
# [17,    19] loss: 0.060
# Epoch
# [17,    28] loss: 0.007
# Epoch
# [17,    37] loss: 0.118
# Epoch
# [17,    46] loss: 0.106
# Epoch
# [18,     1] loss: 0.004
# Epoch
# [18,    10] loss: 0.101
# Epoch
# [18,    19] loss: 0.062
# Epoch
# [18,    28] loss: 0.005
# Epoch
# [18,    37] loss: 0.117
# Epoch
# [18,    46] loss: 0.114
# Epoch
# [19,     1] loss: 0.005
# Epoch
# [19,    10] loss: 0.100
# Epoch
# [19,    19] loss: 0.058
# Epoch
# [19,    28] loss: 0.007
# Epoch
# [19,    37] loss: 0.111
# Epoch
# [19,    46] loss: 0.095
# Epoch
# [20,     1] loss: 0.004
# Epoch
# [20,    10] loss: 0.096
# Epoch
# [20,    19] loss: 0.056
# Epoch
# [20,    28] loss: 0.005
# Epoch
# [20,    37] loss: 0.114
# Epoch
# [20,    46] loss: 0.096
# Epoch
# [21,     1] loss: 0.005
# Epoch
# [21,    10] loss: 0.097
# Epoch
# [21,    19] loss: 0.054
# Epoch
# [21,    28] loss: 0.006
# Epoch
# [21,    37] loss: 0.114
# Epoch
# [21,    46] loss: 0.086
# Epoch
# [22,     1] loss: 0.005
# Epoch
# [22,    10] loss: 0.090
# Epoch
# [22,    19] loss: 0.049
# Epoch
# [22,    28] loss: 0.008
# Epoch
# [22,    37] loss: 0.106
# Epoch
# [22,    46] loss: 0.073
# Epoch
# [23,     1] loss: 0.004
# Epoch
# [23,    10] loss: 0.080
# Epoch
# [23,    19] loss: 0.045
# Epoch
# [23,    28] loss: 0.008
# Epoch
# [23,    37] loss: 0.097
# Epoch
# [23,    46] loss: 0.068
# Epoch
# [24,     1] loss: 0.004
# Epoch
# [24,    10] loss: 0.076
# Epoch
# [24,    19] loss: 0.042
# Epoch
# [24,    28] loss: 0.006
# Epoch
# [24,    37] loss: 0.096
# Epoch
# [24,    46] loss: 0.066
# Epoch
# [25,     1] loss: 0.004
# Epoch
# [25,    10] loss: 0.082
# Epoch
# [25,    19] loss: 0.045
# Epoch
# [25,    28] loss: 0.002
# Epoch
# [25,    37] loss: 0.107
# Epoch
# [25,    46] loss: 0.110
# Epoch
# [26,     1] loss: 0.005
# Epoch
# [26,    10] loss: 0.080
# Epoch
# [26,    19] loss: 0.043
# Epoch
# [26,    28] loss: 0.013
# Epoch
# [26,    37] loss: 0.087
# Epoch
# [26,    46] loss: 0.054
# Epoch
# [27,     1] loss: 0.003
# Epoch
# [27,    10] loss: 0.069
# Epoch
# [27,    19] loss: 0.037
# Epoch
# [27,    28] loss: 0.010
# Epoch
# [27,    37] loss: 0.080
# Epoch
# [27,    46] loss: 0.047
# Epoch
# [28,     1] loss: 0.004
# Epoch
# [28,    10] loss: 0.064
# Epoch
# [28,    19] loss: 0.034
# Epoch
# [28,    28] loss: 0.010
# Epoch
# [28,    37] loss: 0.083
# Epoch
# [28,    46] loss: 0.040
# Epoch
# [29,     1] loss: 0.003
# Epoch
# [29,    10] loss: 0.061
# Epoch
# [29,    19] loss: 0.032
# Epoch
# [29,    28] loss: 0.008
# Epoch
# [29,    37] loss: 0.079
# Epoch
# [29,    46] loss: 0.034
# Epoch
# [30,     1] loss: 0.003
# Epoch
# [30,    10] loss: 0.062
# Epoch
# [30,    19] loss: 0.029
# Epoch
# [30,    28] loss: 0.019
# Epoch
# [30,    37] loss: 0.083
# Epoch
# [30,    46] loss: 0.062
# Epoch
# [31,     1] loss: 0.002
# Epoch
# [31,    10] loss: 0.113
# Epoch
# [31,    19] loss: 0.100
# Epoch
# [31,    28] loss: 0.001
# Epoch
# [31,    37] loss: 0.165
# Epoch
# [31,    46] loss: 0.188
# Epoch
# [32,     1] loss: 0.009
# Epoch
# [32,    10] loss: 0.062
# Epoch
# [32,    19] loss: 0.070
# Epoch
# [32,    28] loss: 0.008
# Epoch
# [32,    37] loss: 0.014
# Epoch
# [32,    46] loss: 0.053
# Epoch
# [33,     1] loss: 0.001
# Epoch
# [33,    10] loss: 0.066
# Epoch
# [33,    19] loss: 0.075
# Epoch
# [33,    28] loss: 0.033
# Epoch
# [33,    37] loss: 0.049
# Epoch
# [33,    46] loss: 0.028
# Epoch
# [34,     1] loss: 0.001
# Epoch
# [34,    10] loss: 0.058
# Epoch
# [34,    19] loss: 0.029
# Epoch
# [34,    28] loss: 0.018
# Epoch
# [34,    37] loss: 0.036
# Epoch
# [34,    46] loss: 0.025
# Epoch
# [35,     1] loss: 0.002
# Epoch
# [35,    10] loss: 0.051
# Epoch
# [35,    19] loss: 0.032
# Epoch
# [35,    28] loss: 0.034
# Epoch
# [35,    37] loss: 0.041
# Epoch
# [35,    46] loss: 0.018
# Epoch
# [36,     1] loss: 0.002
# Epoch
# [36,    10] loss: 0.036
# Epoch
# [36,    19] loss: 0.036
# Epoch
# [36,    28] loss: 0.036
# Epoch
# [36,    37] loss: 0.035
# Epoch
# [36,    46] loss: 0.016
# Epoch
# [37,     1] loss: 0.001
# Epoch
# [37,    10] loss: 0.035
# Epoch
# [37,    19] loss: 0.029
# Epoch
# [37,    28] loss: 0.041
# Epoch
# [37,    37] loss: 0.030
# Epoch
# [37,    46] loss: 0.014
# Epoch
# [38,     1] loss: 0.001
# Epoch
# [38,    10] loss: 0.030
# Epoch
# [38,    19] loss: 0.027
# Epoch
# [38,    28] loss: 0.043
# Epoch
# [38,    37] loss: 0.031
# Epoch
# [38,    46] loss: 0.011
# Epoch
# [39,     1] loss: 0.001
# Epoch
# [39,    10] loss: 0.031
# Epoch
# [39,    19] loss: 0.019
# Epoch
# [39,    28] loss: 0.023
# Epoch
# [39,    37] loss: 0.036
# Epoch
# [39,    46] loss: 0.011
# Epoch
# [40,     1] loss: 0.001
# Epoch
# [40,    10] loss: 0.060
# Epoch
# [40,    19] loss: 0.013
# Epoch
# [40,    28] loss: 0.015
# Epoch
# [40,    37] loss: 0.068
# Epoch
# [40,    46] loss: 0.010
# Epoch
# [41,     1] loss: 0.002
# Epoch
# [41,    10] loss: 0.076
# Epoch
# [41,    19] loss: 0.012
# Epoch
# [41,    28] loss: 0.008
# Epoch
# [41,    37] loss: 0.054
# Epoch
# [41,    46] loss: 0.010
# Epoch
# [42,     1] loss: 0.001
# Epoch
# [42,    10] loss: 0.060
# Epoch
# [42,    19] loss: 0.015
# Epoch
# [42,    28] loss: 0.006
# Epoch
# [42,    37] loss: 0.030
# Epoch
# [42,    46] loss: 0.016
# Epoch
# [43,     1] loss: 0.001
# Epoch
# [43,    10] loss: 0.059
# Epoch
# [43,    19] loss: 0.026
# Epoch
# [43,    28] loss: 0.000
# Epoch
# [43,    37] loss: 0.032
# Epoch
# [43,    46] loss: 0.035
# Epoch
# [44,     1] loss: 0.001
# Epoch
# [44,    10] loss: 0.058
# Epoch
# [44,    19] loss: 0.040
# Epoch
# [44,    28] loss: 0.000
# Epoch
# [44,    37] loss: 0.046
# Epoch
# [44,    46] loss: 0.167
# Epoch
# [45,     1] loss: 0.003
# Epoch
# [45,    10] loss: 0.020
# Epoch
# [45,    19] loss: 0.028
# Epoch
# [45,    28] loss: 0.002
# Epoch
# [45,    37] loss: 0.004
# Epoch
# [45,    46] loss: 0.071
# Epoch
# [46,     1] loss: 0.000
# Epoch
# [46,    10] loss: 0.032
# Epoch
# [46,    19] loss: 0.094
# Epoch
# [46,    28] loss: 0.006
# Epoch
# [46,    37] loss: 0.028
# Epoch
# [46,    46] loss: 0.077
# Epoch
# [47,     1] loss: 0.000
# Epoch
# [47,    10] loss: 0.080
# Epoch
# [47,    19] loss: 0.033
# Epoch
# [47,    28] loss: 0.009
# Epoch
# [47,    37] loss: 0.026
# Epoch
# [47,    46] loss: 0.030
# Epoch
# [48,     1] loss: 0.001
# Epoch
# [48,    10] loss: 0.067
# Epoch
# [48,    19] loss: 0.020
# Epoch
# [48,    28] loss: 0.001
# Epoch
# [48,    37] loss: 0.017
# Epoch
# [48,    46] loss: 0.038
# Epoch
# [49,     1] loss: 0.002
# Epoch
# [49,    10] loss: 0.069
# Epoch
# [49,    19] loss: 0.016
# Epoch
# [49,    28] loss: 0.002
# Epoch
# [49,    37] loss: 0.027
# Epoch
# [49,    46] loss: 0.030
# Epoch
# [50,     1] loss: 0.001
# Epoch
# [50,    10] loss: 0.054
# Epoch
# [50,    19] loss: 0.009
# Epoch
# [50,    28] loss: 0.015
# Epoch
# [50,    37] loss: 0.019
# Epoch
# [50,    46] loss: 0.011
# Epoch
# [51,     1] loss: 0.001
# Epoch
# [51,    10] loss: 0.025
# Epoch
# [51,    19] loss: 0.055
# Epoch
# [51,    28] loss: 0.052
# Epoch
# [51,    37] loss: 0.023
# Epoch
# [51,    46] loss: 0.003
# Epoch
# [52,     1] loss: 0.000
# Epoch
# [52,    10] loss: 0.014
# Epoch
# [52,    19] loss: 0.024
# Epoch
# [52,    28] loss: 0.002
# Epoch
# [52,    37] loss: 0.005
# Epoch
# [52,    46] loss: 0.081
# Epoch
# [53,     1] loss: 0.000
# Epoch
# [53,    10] loss: 0.020
# Epoch
# [53,    19] loss: 0.053
# Epoch
# [53,    28] loss: 0.005
# Epoch
# [53,    37] loss: 0.009
# Epoch
# [53,    46] loss: 0.068
# Epoch
# [54,     1] loss: 0.000
# Epoch
# [54,    10] loss: 0.016
# Epoch
# [54,    19] loss: 0.031
# Epoch
# [54,    28] loss: 0.001
# Epoch
# [54,    37] loss: 0.004
# Epoch
# [54,    46] loss: 0.065
# Epoch
# [55,     1] loss: 0.001
# Epoch
# [55,    10] loss: 0.010
# Epoch
# [55,    19] loss: 0.018
# Epoch
# [55,    28] loss: 0.000
# Epoch
# [55,    37] loss: 0.004
# Epoch
# [55,    46] loss: 0.031
# Epoch
# [56,     1] loss: 0.000
# Epoch
# [56,    10] loss: 0.010
# Epoch
# [56,    19] loss: 0.024
# Epoch
# [56,    28] loss: 0.000
# Epoch
# [56,    37] loss: 0.005
# Epoch
# [56,    46] loss: 0.035
# Epoch
# [57,     1] loss: 0.000
# Epoch
# [57,    10] loss: 0.012
# Epoch
# [57,    19] loss: 0.016
# Epoch
# [57,    28] loss: 0.000
# Epoch
# [57,    37] loss: 0.005
# Epoch
# [57,    46] loss: 0.018
# Epoch
# [58,     1] loss: 0.000
# Epoch
# [58,    10] loss: 0.009
# Epoch
# [58,    19] loss: 0.012
# Epoch
# [58,    28] loss: 0.000
# Epoch
# [58,    37] loss: 0.010
# Epoch
# [58,    46] loss: 0.014
# Epoch
# [59,     1] loss: 0.000
# Epoch
# [59,    10] loss: 0.005
# Epoch
# [59,    19] loss: 0.006
# Epoch
# [59,    28] loss: 0.000
# Epoch
# [59,    37] loss: 0.012
# Epoch
# [59,    46] loss: 0.014
# Epoch
# [60,     1] loss: 0.000
# Epoch
# [60,    10] loss: 0.004
# Epoch
# [60,    19] loss: 0.005
# Epoch
# [60,    28] loss: 0.000
# Epoch
# [60,    37] loss: 0.009
# Epoch
# [60,    46] loss: 0.006
# Epoch
# [61,     1] loss: 0.000
# Epoch
# [61,    10] loss: 0.003
# Epoch
# [61,    19] loss: 0.006
# Epoch
# [61,    28] loss: 0.000
# Epoch
# [61,    37] loss: 0.005
# Epoch
# [61,    46] loss: 0.004
# Epoch
# [62,     1] loss: 0.000
# Epoch
# [62,    10] loss: 0.002
# Epoch
# [62,    19] loss: 0.004
# Epoch
# [62,    28] loss: 0.000
# Epoch
# [62,    37] loss: 0.004
# Epoch
# [62,    46] loss: 0.004
# Epoch
# [63,     1] loss: 0.000
# Epoch
# [63,    10] loss: 0.002
# Epoch
# [63,    19] loss: 0.004
# Epoch
# [63,    28] loss: 0.000
# Epoch
# [63,    37] loss: 0.004
# Epoch
# [63,    46] loss: 0.003
# Epoch
# [64,     1] loss: 0.000
# Epoch
# [64,    10] loss: 0.002
# Epoch
# [64,    19] loss: 0.003
# Epoch
# [64,    28] loss: 0.000
# Epoch
# [64,    37] loss: 0.003
# Epoch
# [64,    46] loss: 0.003
# Epoch
# [65,     1] loss: 0.000
# Epoch
# [65,    10] loss: 0.002
# Epoch
# [65,    19] loss: 0.003
# Epoch
# [65,    28] loss: 0.000
# Epoch
# [65,    37] loss: 0.003
# Epoch
# [65,    46] loss: 0.003
# Epoch
# [66,     1] loss: 0.000
# Epoch
# [66,    10] loss: 0.001
# Epoch
# [66,    19] loss: 0.003
# Epoch
# [66,    28] loss: 0.000
# Epoch
# [66,    37] loss: 0.002
# Epoch
# [66,    46] loss: 0.002
# Epoch
# [67,     1] loss: 0.000
# Epoch
# [67,    10] loss: 0.001
# Epoch
# [67,    19] loss: 0.002
# Epoch
# [67,    28] loss: 0.000
# Epoch
# [67,    37] loss: 0.002
# Epoch
# [67,    46] loss: 0.002
# Epoch
# [68,     1] loss: 0.000
# Epoch
# [68,    10] loss: 0.001
# Epoch
# [68,    19] loss: 0.002
# Epoch
# [68,    28] loss: 0.000
# Epoch
# [68,    37] loss: 0.002
# Epoch
# [68,    46] loss: 0.002
# Epoch
# [69,     1] loss: 0.000
# Epoch
# [69,    10] loss: 0.001
# Epoch
# [69,    19] loss: 0.002
# Epoch
# [69,    28] loss: 0.000
# Epoch
# [69,    37] loss: 0.002
# Epoch
# [69,    46] loss: 0.002
# Epoch
# [70,     1] loss: 0.000
# Epoch
# [70,    10] loss: 0.001
# Epoch
# [70,    19] loss: 0.002
# Epoch
# [70,    28] loss: 0.000
# Epoch
# [70,    37] loss: 0.002
# Epoch
# [70,    46] loss: 0.002
# Epoch
# [71,     1] loss: 0.000
# Epoch
# [71,    10] loss: 0.001
# Epoch
# [71,    19] loss: 0.002
# Epoch
# [71,    28] loss: 0.000
# Epoch
# [71,    37] loss: 0.002
# Epoch
# [71,    46] loss: 0.002
# Epoch
# [72,     1] loss: 0.000
# Epoch
# [72,    10] loss: 0.001
# Epoch
# [72,    19] loss: 0.002
# Epoch
# [72,    28] loss: 0.000
# Epoch
# [72,    37] loss: 0.001
# Epoch
# [72,    46] loss: 0.002
# Epoch
# [73,     1] loss: 0.000
# Epoch
# [73,    10] loss: 0.001
# Epoch
# [73,    19] loss: 0.002
# Epoch
# [73,    28] loss: 0.000
# Epoch
# [73,    37] loss: 0.001
# Epoch
# [73,    46] loss: 0.001
# Epoch
# [74,     1] loss: 0.000
# Epoch
# [74,    10] loss: 0.001
# Epoch
# [74,    19] loss: 0.001
# Epoch
# [74,    28] loss: 0.000
# Epoch
# [74,    37] loss: 0.001
# Epoch
# [74,    46] loss: 0.001
# Epoch
# [75,     1] loss: 0.000
# Epoch
# [75,    10] loss: 0.001
# Epoch
# [75,    19] loss: 0.001
# Epoch
# [75,    28] loss: 0.000
# Epoch
# [75,    37] loss: 0.001
# Epoch
# [75,    46] loss: 0.001
# Epoch
# [76,     1] loss: 0.000
# Epoch
# [76,    10] loss: 0.001
# Epoch
# [76,    19] loss: 0.001
# Epoch
# [76,    28] loss: 0.000
# Epoch
# [76,    37] loss: 0.001
# Epoch
# [76,    46] loss: 0.001
# Epoch
# [77,     1] loss: 0.000
# Epoch
# [77,    10] loss: 0.001
# Epoch
# [77,    19] loss: 0.001
# Epoch
# [77,    28] loss: 0.000
# Epoch
# [77,    37] loss: 0.001
# Epoch
# [77,    46] loss: 0.001
# Epoch
# [78,     1] loss: 0.000
# Epoch
# [78,    10] loss: 0.001
# Epoch
# [78,    19] loss: 0.001
# Epoch
# [78,    28] loss: 0.000
# Epoch
# [78,    37] loss: 0.001
# Epoch
# [78,    46] loss: 0.001
# Epoch
# [79,     1] loss: 0.000
# Epoch
# [79,    10] loss: 0.001
# Epoch
# [79,    19] loss: 0.001
# Epoch
# [79,    28] loss: 0.000
# Epoch
# [79,    37] loss: 0.001
# Epoch
# [79,    46] loss: 0.001
# Epoch
# [80,     1] loss: 0.000
# Epoch
# [80,    10] loss: 0.001
# Epoch
# [80,    19] loss: 0.001
# Epoch
# [80,    28] loss: 0.000
# Epoch
# [80,    37] loss: 0.001
# Epoch
# [80,    46] loss: 0.001
# Epoch
# [81,     1] loss: 0.000
# Epoch
# [81,    10] loss: 0.001
# Epoch
# [81,    19] loss: 0.001
# Epoch
# [81,    28] loss: 0.000
# Epoch
# [81,    37] loss: 0.001
# Epoch
# [81,    46] loss: 0.001
# Epoch
# [82,     1] loss: 0.000
# Epoch
# [82,    10] loss: 0.001
# Epoch
# [82,    19] loss: 0.001
# Epoch
# [82,    28] loss: 0.000
# Epoch
# [82,    37] loss: 0.001
# Epoch
# [82,    46] loss: 0.001
# Epoch
# [83,     1] loss: 0.000
# Epoch
# [83,    10] loss: 0.000
# Epoch
# [83,    19] loss: 0.001
# Epoch
# [83,    28] loss: 0.000
# Epoch
# [83,    37] loss: 0.001
# Epoch
# [83,    46] loss: 0.001
# Epoch
# [84,     1] loss: 0.000
# Epoch
# [84,    10] loss: 0.000
# Epoch
# [84,    19] loss: 0.001
# Epoch
# [84,    28] loss: 0.000
# Epoch
# [84,    37] loss: 0.001
# Epoch
# [84,    46] loss: 0.001
# Epoch
# [85,     1] loss: 0.000
# Epoch
# [85,    10] loss: 0.000
# Epoch
# [85,    19] loss: 0.001
# Epoch
# [85,    28] loss: 0.000
# Epoch
# [85,    37] loss: 0.001
# Epoch
# [85,    46] loss: 0.001
# Epoch
# [86,     1] loss: 0.000
# Epoch
# [86,    10] loss: 0.000
# Epoch
# [86,    19] loss: 0.001
# Epoch
# [86,    28] loss: 0.000
# Epoch
# [86,    37] loss: 0.001
# Epoch
# [86,    46] loss: 0.001
# Epoch
# [87,     1] loss: 0.000
# Epoch
# [87,    10] loss: 0.000
# Epoch
# [87,    19] loss: 0.001
# Epoch
# [87,    28] loss: 0.000
# Epoch
# [87,    37] loss: 0.001
# Epoch
# [87,    46] loss: 0.001
# Epoch
# [88,     1] loss: 0.000
# Epoch
# [88,    10] loss: 0.000
# Epoch
# [88,    19] loss: 0.001
# Epoch
# [88,    28] loss: 0.000
# Epoch
# [88,    37] loss: 0.001
# Epoch
# [88,    46] loss: 0.001
# Epoch
# [89,     1] loss: 0.000
# Epoch
# [89,    10] loss: 0.000
# Epoch
# [89,    19] loss: 0.001
# Epoch
# [89,    28] loss: 0.000
# Epoch
# [89,    37] loss: 0.001
# Epoch
# [89,    46] loss: 0.001
# Epoch
# [90,     1] loss: 0.000
# Epoch
# [90,    10] loss: 0.000
# Epoch
# [90,    19] loss: 0.001
# Epoch
# [90,    28] loss: 0.000
# Epoch
# [90,    37] loss: 0.001
# Epoch
# [90,    46] loss: 0.001
# Epoch
# [91,     1] loss: 0.000
# Epoch
# [91,    10] loss: 0.000
# Epoch
# [91,    19] loss: 0.001
# Epoch
# [91,    28] loss: 0.000
# Epoch
# [91,    37] loss: 0.001
# Epoch
# [91,    46] loss: 0.001
# Epoch
# [92,     1] loss: 0.000
# Epoch
# [92,    10] loss: 0.000
# Epoch
# [92,    19] loss: 0.001
# Epoch
# [92,    28] loss: 0.000
# Epoch
# [92,    37] loss: 0.001
# Epoch
# [92,    46] loss: 0.001
# Epoch
# [93,     1] loss: 0.000
# Epoch
# [93,    10] loss: 0.000
# Epoch
# [93,    19] loss: 0.001
# Epoch
# [93,    28] loss: 0.000
# Epoch
# [93,    37] loss: 0.001
# Epoch
# [93,    46] loss: 0.001
# Epoch
# [94,     1] loss: 0.000
# Epoch
# [94,    10] loss: 0.000
# Epoch
# [94,    19] loss: 0.001
# Epoch
# [94,    28] loss: 0.000
# Epoch
# [94,    37] loss: 0.001
# Epoch
# [94,    46] loss: 0.001
# Epoch
# [95,     1] loss: 0.000
# Epoch
# [95,    10] loss: 0.000
# Epoch
# [95,    19] loss: 0.001
# Epoch
# [95,    28] loss: 0.000
# Epoch
# [95,    37] loss: 0.000
# Epoch
# [95,    46] loss: 0.001
# Epoch
# [96,     1] loss: 0.000
# Epoch
# [96,    10] loss: 0.000
# Epoch
# [96,    19] loss: 0.001
# Epoch
# [96,    28] loss: 0.000
# Epoch
# [96,    37] loss: 0.000
# Epoch
# [96,    46] loss: 0.001
# Epoch
# [97,     1] loss: 0.000
# Epoch
# [97,    10] loss: 0.000
# Epoch
# [97,    19] loss: 0.001
# Epoch
# [97,    28] loss: 0.000
# Epoch
# [97,    37] loss: 0.000
# Epoch
# [97,    46] loss: 0.001
# Epoch
# [98,     1] loss: 0.000
# Epoch
# [98,    10] loss: 0.000
# Epoch
# [98,    19] loss: 0.001
# Epoch
# [98,    28] loss: 0.000
# Epoch
# [98,    37] loss: 0.000
# Epoch
# [98,    46] loss: 0.001
# Epoch
# [99,     1] loss: 0.000
# Epoch
# [99,    10] loss: 0.000
# Epoch
# [99,    19] loss: 0.001
# Epoch
# [99,    28] loss: 0.000
# Epoch
# [99,    37] loss: 0.000
# Epoch
# [99,    46] loss: 0.001
# Epoch
# [100,     1] loss: 0.000
# Epoch
# [100,    10] loss: 0.000
# Epoch
# [100,    19] loss: 0.001
# Epoch
# [100,    28] loss: 0.000
# Epoch
# [100,    37] loss: 0.000
# Epoch
# [100,    46] loss: 0.000
# tensor([[-4.1397,  3.6388],
#         [ 6.0846, -6.2447],
#         [ 7.9544, -8.5262],
#         [-8.6579,  7.8066],
#         [-7.9917,  7.2365]]) tensor([1, 0, 0, 1, 1])
# tensor([[ 12.6182, -13.0878],
#         [ -0.2193,  -0.0675],
#         [ -9.3659,   8.4181],
#         [  5.4180,  -5.6405],
#         [-16.8799,  15.2853]]) tensor([0, 1, 1, 0, 1])
# tensor([[  6.1215,  -6.3471],
#         [ -3.4097,   2.9984],
#         [  9.0225,  -9.4195],
#         [-17.6211,  16.0156],
#         [ -5.3639,   4.8553]]) tensor([0, 1, 0, 1, 1])
# tensor([[ 11.1429, -11.5814],
#         [ -3.8836,   3.4258],
#         [ -0.0237,  -0.3604],
#         [ 15.6052, -16.1854],
#         [  6.7968,  -7.1157]]) tensor([0, 1, 0, 0, 0])
# tensor([[-15.1681,  13.7814],
#         [-16.4406,  14.9985],
#         [  5.0062,  -5.2937],
#         [ -8.5150,   7.6479],
#         [-17.9206,  16.3017]]) tensor([1, 1, 0, 1, 1])
# tensor([[ 18.2869, -18.9017],
#         [  8.3641,  -8.7213],
#         [  9.6127,  -9.9845],
#         [ -4.9825,   4.4106],
#         [ -7.9891,   7.2025]]) tensor([0, 0, 0, 1, 1])
# tensor([[-26.3412,  23.9990],
#         [-11.1105,  10.0550],
#         [ -5.0142,   4.2360],
#         [-20.6025,  18.8921],
#         [ -4.5276,   3.9777]]) tensor([1, 1, 1, 1, 1])
# tensor([[ -2.6235,   2.1507],
#         [  6.3754,  -6.7134],
#         [ -6.0801,   5.4997],
#         [  8.8644,  -9.2427],
#         [-10.2946,   9.3097]]) tensor([1, 0, 1, 0, 1])
# tensor([[-22.5101,  20.5105],
#         [  2.6550,  -2.9782],
#         [  7.7035,  -8.0033],
#         [ -8.2477,   7.4314],
#         [  6.6212,  -6.9346]]) tensor([1, 0, 0, 1, 0])
# tensor([[ 10.5543, -10.9401],
#         [-22.8895,  20.8927],
#         [  9.9937, -10.4100],
#         [  8.4613,  -8.8459],
#         [  8.6597,  -9.1425]]) tensor([0, 1, 0, 0, 0])
# tensor([[  5.7285,  -5.9929],
#         [ -5.7367,   5.1757],
#         [-27.5645,  25.1702],
#         [ -4.0995,   3.6569],
#         [ -6.7374,   6.0857]]) tensor([0, 1, 1, 1, 1])
# tensor([[  4.6885,  -5.1249],
#         [ 21.8173, -22.5099],
#         [  8.0272,  -8.3631],
#         [-27.4094,  25.0558],
#         [ 10.9973, -11.3904]]) tensor([0, 0, 0, 1, 0])
# tensor([[-29.4306,  26.9005],
#         [  8.7390,  -9.0877],
#         [ 11.2675, -11.7014],
#         [-12.4151,  11.3158],
#         [ -8.6026,   7.7161]]) tensor([1, 0, 0, 1, 1])
# tensor([[ -3.6911,   3.2868],
#         [-23.0126,  21.0226],
#         [  3.5470,  -3.7812],
#         [  7.9219,  -8.2929],
#         [-13.0618,  11.7499]]) tensor([1, 1, 0, 0, 1])
# tensor([[ -3.6433,   3.1903],
#         [ 13.9297, -14.4816],
#         [-12.0934,  10.9536],
#         [  4.9186,  -5.1805],
#         [-11.2485,  10.2074]]) tensor([1, 0, 1, 0, 1])
# tensor([[ 10.0028, -10.4091],
#         [-14.1362,  12.8651],
#         [  8.2036,  -8.5464],
#         [ 10.4300, -10.8529],
#         [-16.9650,  15.4140]]) tensor([0, 1, 0, 0, 1])
# Accuracy for class: blue  is 97.2 %
# Accuracy for class: green is 95.5 %
